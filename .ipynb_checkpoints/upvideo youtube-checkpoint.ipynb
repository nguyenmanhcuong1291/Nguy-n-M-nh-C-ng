# %%
import os
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
import json
import time

# Scopes cần thiết để truy cập YouTube Data API
scopes = ["https://www.googleapis.com/auth/youtube.force-ssl"]

# Tên thư mục chứa video
VIDEO_FOLDER = 'C:\\Users\\nguyenmanhcuong1991\\Desktop\\video\\'

# Tạo hàm để xác thực và ủy quyền
def get_authenticated_service():
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
    flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
        "client_secret.json", scopes)
    credentials = flow.run_local_server(port=8080, access_type='offline', prompt='consent')
    return googleapiclient.discovery.build("youtube", "v3", credentials=credentials)

# Hàm upload video lên YouTube
def upload_video(youtube, file, title, description, category, tags, privacyStatus):
    body = {
        "snippet": {
            "title": title,
            "description": description,
            "tags": tags,
            "categoryId": category
        },
        "status": {
            "privacyStatus": privacyStatus
        }
    }

    insert_request = youtube.videos().insert(
        part="snippet,status",
        body=body,
        media_body=file
    )

    response = insert_request.execute()
    return response["id"]

# Hàm tạo playlist
def create_playlist(youtube, title, description, privacyStatus):
    body = {
        "snippet": {
            "title": title,
            "description": description
        },
        "status": {
            "privacyStatus": privacyStatus
        }
    }

    playlists_insert_request = youtube.playlists().insert(
        part="snippet,status",
        body=body
    )

    response = playlists_insert_request.execute()
    return response["id"]

# Hàm thêm video vào playlist
def add_video_to_playlist(youtube, video_id, playlist_id):
    add_video_request = youtube.playlistItems().insert(
        part="snippet",
        body={
            "snippet": {
                "playlistId": playlist_id,
                "resourceId": {
                    "kind": "youtube#video",
                    "videoId": video_id
                }
            }
        }
    )

    add_video_request.execute()

def main():
    youtube = get_authenticated_service()

    try:
        # Kiểm tra danh sách video có sẵn trên YouTube và lưu trữ ID vào một tập hợp
        existing_videos = set()
        search_request = youtube.search().list(
            part="snippet",
            forMine=True,
            type="video",
            maxResults=50  # Số lượng video tối đa trong mỗi lần gọi
        )
        while search_request:
            try:
                search_response = search_request.execute()
                for item in search_response.get("items", []):
                    existing_videos.add(item["snippet"]["title"])  # Corrected to add only videoId
                search_request = youtube.search().list_next(search_request, search_response)
            except googleapiclient.errors.HttpError as e:
                if e.resp.status in [403] and 'quotaExceeded' in e.content.decode():
                    print('Quota exceeded, waiting for quota reset.')
                    time.sleep(600)  # Chờ 10 phút trước khi thử lại
                else:
                    raise e

        # Kiểm tra danh sách playlist có sẵn trên YouTube và lưu trữ ID vào một từ điển
        existing_playlists = {}
        playlist_request = youtube.playlists().list(
            part="snippet",
            mine=True,
            maxResults=50  # Số lượng playlist tối đa trong mỗi lần gọi
        )
        while playlist_request:
            try:
                playlist_response = playlist_request.execute()
                for playlist in playlist_response.get("items", []):
                    existing_playlists[playlist["snippet"]["title"]] = playlist["id"]
                playlist_request = youtube.playlists().list_next(playlist_request, playlist_response)
                print("playlist_request: ",playlist_request)
                print("playlist_response: ",playlist_response)
                print("existing_playlists: ",existing_playlists)
            except googleapiclient.errors.HttpError as e:
                if e.resp.status in [403] and 'quotaExceeded' in e.content.decode():
                    print('Quota exceeded, waiting for quota reset.')
                    time.sleep(600)  # Chờ 10 phút trước khi thử lại
                else:
                    raise e

        # Lặp qua danh sách tệp video trong thư mục
        for file in os.listdir(VIDEO_FOLDER):
            if file.endswith(".mp4"):
                parts = file.split('-')
                lop = parts[0]
                video_number = parts[1].split('.')[0]

                title = f"{lop}-{video_number}"
                description = f"Description for {title}"
                category = "22"  # Category ID cho Education
                tags = ["tag1", "tag2"]
                privacyStatus = "public"

                try:
                    if title not in existing_videos:
                        # Nếu video chưa tồn tại trên YouTube, thực hiện tải lên
                        video_id = upload_video(youtube, os.path.join(VIDEO_FOLDER, file), title, description, category, tags, privacyStatus)
                        print(f"Uploaded video '{title}' with ID: {video_id}")

                        # Tạo playlist nếu playlist chưa tồn tại
                        if lop not in existing_playlists:
                            playlist_id = create_playlist(youtube, lop, f"Playlist for {lop}", "public")
                            existing_playlists[lop] = playlist_id
                            print(f"Created playlist '{lop}' with ID: {playlist_id}")

                        # Thêm video vào playlist
                        add_video_to_playlist(youtube, video_id, existing_playlists[lop])
                        print(f"Added video '{title}' to playlist '{lop}' with ID: {existing_playlists[lop]}")

                        # Thêm ID video mới vào tập hợp các video đã tồn tại
                        existing_videos.add(video_id)
                    else:
                        print(f"Video '{title}' already exists on YouTube")

                    # Thời gian nghỉ giữa các lần gọi API để tránh bị giới hạn
                    time.sleep(60)
                except googleapiclient.errors.HttpError as e:
                    if e.resp.status in [403] and 'quotaExceeded' in e.content.decode():
                        print('Quota exceeded, waiting for quota reset.')
                        time.sleep(600)  # Chờ 10 phút trước khi thử lại
                    else:
                        raise e

    except Exception as e:
        print("An error occurred:", e)

if __name__ == "__main__":
    main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=148844415977-ksprmc5lasve02hvgkq3qhuealkj9v3t.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=mqHDcxvVLv8CG6elcszDVnh66M7xts&access_type=offline&prompt=consent
# playlist_request:  None
# playlist_response:  {'kind': 'youtube#playlistListResponse', 'etag': 'jtLF0DwK5Dy0M1NSwrWDkGuzNso', 'pageInfo': {'totalResults': 7, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#playlist', 'etag': 'gf8OF9KnwTWJdAzcM2_1vDHOe6w', 'id': 'PLZJuZFTDSB2djlnjYsOBeRAHhN9RjnCuY', 'snippet': {'publishedAt': '2024-05-22T04:20:43Z', 'channelId': 'UCds4T2OHHTE3oIIQQd9Ok4g', 'title': 'lop4', 'description': 'Playlist for lop4', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ADZwP3DXjtI/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/ADZwP3DXjtI/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/ADZwP3DXjtI/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/ADZwP3DXjtI/sddefault.jpg', 'width': 640, 'height': 480}}, 'channelTitle': 'Mạnh Cường Nguyễn', 'localized': {'title': 'lop4', 'description': 'Playlist for lop4'}}}, {'kind': 'youtube#playlist', 'etag': 'rXmhPgev0eLjOgcFE1qVgPP5zBQ', 'id': 'PLZJuZFTDSB2cHg2iPyh3RQEQeeAVSp-v1', 'snippet': {'publishedAt': '2024-05-17T08:24:39Z', 'channelId': 'UCds4T2OHHTE3oIIQQd9Ok4g', 'title': 'lop3', 'description': 'Playlist for lop3', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Mạnh Cường Nguyễn', 'localized': {'title': 'lop3', 'description': 'Playlist for lop3'}}}, {'kind': 'youtube#playlist', 'etag': '9cEoS30IMTu-KOHconFJgAKn2E8', 'id': 'PLZJuZFTDSB2cKy56OMGAAOPdKqpqZk3BA', 'snippet': {'publishedAt': '2024-05-17T08:24:11Z', 'channelId': 'UCds4T2OHHTE3oIIQQd9Ok4g', 'title': 'lop2', 'description': 'Playlist for lop2', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Mạnh Cường Nguyễn', 'localized': {'title': 'lop2', 'description': 'Playlist for lop2'}}}, {'kind': 'youtube#playlist', 'etag': '-txztc5NjgBB0gVE10v6owxCoGY', 'id': 'PLZJuZFTDSB2cUQyEglBU3gGH5xQh_tWf2', 'snippet': {'publishedAt': '2024-05-17T08:23:44Z', 'channelId': 'UCds4T2OHHTE3oIIQQd9Ok4g', 'title': 'lop1', 'description': 'Playlist for lop1', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/img/no_thumbnail.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Mạnh Cường Nguyễn', 'localized': {'title': 'lop1', 'description': 'Playlist for lop1'}}}, {'kind': 'youtube#playlist', 'etag': 'z09GjO-rShWzekZHxzMiY7FB02U', 'id': 'PLZJuZFTDSB2eSnHJ_E75JjSLKDOJCmP4d', 'snippet': {'publishedAt': '2024-03-07T14:06:33Z', 'channelId': 'UCds4T2OHHTE3oIIQQd9Ok4g', 'title': 'python - mô hình hồi quy', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1lC-uX26P_s/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/1lC-uX26P_s/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/1lC-uX26P_s/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Mạnh Cường Nguyễn', 'localized': {'title': 'python - mô hình hồi quy', 'description': ''}}}, {'kind': 'youtube#playlist', 'etag': 'J7uo9_3Dq7Cg2zMGcHY8frqmffQ', 'id': 'PLZJuZFTDSB2fe5izCsatkyfU7s_OIyFLv', 'snippet': {'publishedAt': '2020-06-04T18:29:46Z', 'channelId': 'UCds4T2OHHTE3oIIQQd9Ok4g', 'title': 'đêm tỏ tình', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qDvKVxFe7VA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/qDvKVxFe7VA ...
# existing_playlists:  {'lop4': 'PLZJuZFTDSB2djlnjYsOBeRAHhN9RjnCuY', 'lop3': 'PLZJuZFTDSB2cHg2iPyh3RQEQeeAVSp-v1', 'lop2': 'PLZJuZFTDSB2cKy56OMGAAOPdKqpqZk3BA', 'lop1': 'PLZJuZFTDSB2cUQyEglBU3gGH5xQh_tWf2', 'python - mô hình hồi quy': 'PLZJuZFTDSB2eSnHJ_E75JjSLKDOJCmP4d', 'đêm tỏ tình': 'PLZJuZFTDSB2fe5izCsatkyfU7s_OIyFLv'}
# Video 'lop10-video1' already exists on YouTube
# Video 'lop3-video2' already exists on YouTube
# Video 'lop4-video1' already exists on YouTube
# Uploaded video 'lop4-video2' with ID: ApnU2B1d94E
# Added video 'lop4-video2' to playlist 'lop4' with ID: PLZJuZFTDSB2djlnjYsOBeRAHhN9RjnCuY
